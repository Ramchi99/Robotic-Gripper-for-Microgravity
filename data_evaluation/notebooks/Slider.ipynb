# %% [markdown]
# # Spacehopper Gripper Data Evaluation\nThis notebook processes the raw ROS logs from the physical gripper tests on various rock surfaces. It trims the initial offsets, identifies the point of slippage (when Tangential Force Fx drops), and plots the Maximum Normal Force (Fz) vs Tangential Force prior to slippage. The calculated statistics are then used to evaluate the gripper's holding performance.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mean, stdev

# %%
Se_1 = 3.02166748046875
Se_2 = 2.65960693359375
Se_3 = 2.056343587239583

Sc_1 = 1.1877766927083333
Sc_2 = 2.297538248697917
Sc_3 = 2.0752685546875

Ma_1 = 2.5954833984375
Ma_2 = 2.5985677083333334
Ma_3 = 3.7315633138020834

La_1 = 8.2184814453125
La_2 = 5.009932454427084
La_3 = 5.297627766927083

Ka_1 = 2.0346720377604166
Ka_2 = 4.472017415364583
Ka_3 = 2.62264404296875

As_1 = 3.083048502604167
As_2 = 1.4817342122395833
As_3 = 1.4466878255208333

# %%
Array = [Se_1, Se_2, Se_3, Sc_1, Sc_2, Sc_3, Ma_1, Ma_2, Ma_3, La_1, La_2, La_3, Ka_1, Ka_2, Ka_3, As_1, As_2, As_3]

# %%
avg_slider = mean(Array)
std_slider = stdev(Array)

print(avg_slider)
print(std_slider)
# Out:
# 3.1050367567274306
# 1.728962694025502
