# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_forces(df, cut_1=0, cut_2=None, avg_end=None, fx_threshold=1, offset_position='beginning', offset_length=10):
    """
    Plots the Tangential Force (Fx) and Normal Force (Fz) from the given DataFrame with offsets
    and within a specified range.

    Parameters:
    df (pd.DataFrame): The DataFrame containing force data with columns 'Fx' and 'Fz'.
    cut_1 (int): The starting index for the range of data to be plotted.
    cut_2 (int or None): The ending index for the range of data to be plotted. If None, plot till the end.

    Returns:
    None
    """
    if offset_position == 'beginning':
        # Calculate the offsets as the average of the first 20 entries
        offset_x = df['Fx'][:offset_length].mean()
        offset_z = df['Fz'][:offset_length].mean()
    elif offset_position == 'end':
        # Calculate the offsets as the average of the last 20 entries
        offset_x = df['Fx'][-offset_length:].mean()
        offset_z = df['Fz'][-offset_length:].mean()
    else:
        raise ValueError("Invalid offset_position. Choose either 'beginning' or 'end'.")

    # If avg_end is not provided, use cut_2
    avg_end = avg_end if avg_end is not None else cut_2

    # If avg_end is not None, calculate the length from cut_1 to avg_end
    if avg_end is not None and cut_1 is not None:
        length_cut_to_avg = avg_end - cut_1
        print(f"Length from cut_1 to avg_end: {length_cut_to_avg}")

    # Calculate average values of Fx and Fz in the defined averaging interval
    avg_fx = df[cut_1:avg_end]['Fx'].mean() - offset_x
    avg_fz = df[cut_1:avg_end]['Fz'].mean() - offset_z

    # Apply the cut range to the DataFrame
    df_cut = df[cut_1:cut_2].copy()
    
    # Find the maximum Fz and corresponding timestep
    max_fz = df_cut['Fz'].max() - offset_z
    max_fz_timestep = df_cut['Fz'].idxmax()

    # Find the timestep where Fx drops below the threshold
    fx_drop_timestep = df_cut[df_cut['Fx'] - offset_x < fx_threshold].index.min()
    
    # Print the average values
    print(f"Average Fx in the averaging interval [{cut_1}:{avg_end}]: {avg_fx}")
    print(f"Average Fz in the averaging interval [{cut_1}:{avg_end}]: {avg_fz}")
    print(f"Maximum Fz in the plotting interval [{cut_1}:{cut_2}]: {max_fz} at timestep {max_fz_timestep}")
    print(f"Time step where Fx drops below {fx_threshold}: {fx_drop_timestep}")
    
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'] - offset_x, label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'] - offset_z, label='Normal Force (Fz)', alpha=0.7)
    plt.axvline(x=max_fz_timestep, color='r', linestyle='--', label='Max Fz', alpha=0.2)
    plt.axvline(x=fx_drop_timestep, color='g', linestyle='--', label=f'Fx < {fx_threshold}', alpha=0.2)
    plt.xlabel('Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Tangential vs Normal Force (Offset Adjusted)')
    plt.grid()
    plt.show()

    # Apply the offsets to the cut DataFrame
    df_cut['Fx'] = df_cut['Fx'] - offset_x
    df_cut['Fz'] = df_cut['Fz'] - offset_z
    
    # Shift the index so it starts at 0 if cut_1 is not None
    if cut_1 is not None:
        df_cut.index = df_cut.index - cut_1

    # Return the modified DataFrame
    return df_cut, (length_cut_to_avg if avg_end is not None and cut_1 is not None else None)

# %% [markdown]
# <font size="6">Lavarock 50°</font>

# %% [markdown]
# <font size="6">Test 1: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231553.csv"
df = pd.read_csv(data)
test_1, end_1 = plot_forces(df, cut_1=450, cut_2=None, avg_end=1476, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 1026
# Average Fx in the averaging interval [450:1476]: 4.966135402822587
# Average Fz in the averaging interval [450:1476]: 1.8371006420946028
# Maximum Fz in the plotting interval [450:None]: 4.563297526041667 at timestep 1456
# Time step where Fx drops below 1: 1476

# %% [markdown]
# <font size="6">Test 2: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231556.csv"
df = pd.read_csv(data)
test_2, end_2 = plot_forces(df, cut_1=950, cut_2=None, avg_end=2310, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 1360
# Average Fx in the averaging interval [950:2310]: 5.563653035491121
# Average Fz in the averaging interval [950:2310]: 4.307369321935317
# Maximum Fz in the plotting interval [950:None]: 7.78170166015625 at timestep 2256
# Time step where Fx drops below 1: 2310

# %% [markdown]
# <font size="6">Test 3: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231600.csv"
df = pd.read_csv(data)
test_3, end_3 = plot_forces(df, cut_1=556, cut_2=None, avg_end=1626, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 1070
# Average Fx in the averaging interval [556:1626]: 5.007598008842112
# Average Fz in the averaging interval [556:1626]: 2.3321379189179323
# Maximum Fz in the plotting interval [556:None]: 4.28729248046875 at timestep 1586
# Time step where Fx drops below 1: 1626

# %% [markdown]
# <font size="6">Test 4: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231602.csv"
df = pd.read_csv(data)
test_4, end_4 = plot_forces(df, cut_1=1120, cut_2=None, avg_end=1677, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 557
# Average Fx in the averaging interval [1120:1677]: 5.1654341104428685
# Average Fz in the averaging interval [1120:1677]: 1.8472666696471984
# Maximum Fz in the plotting interval [1120:None]: 3.734061686197917 at timestep 1664
# Time step where Fx drops below 1: 1677

# %% [markdown]
# <font size="6">Test 5a: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231604.csv"
df = pd.read_csv(data)
test_5a, end_5a = plot_forces(df, cut_1=970, cut_2=1150, avg_end=1083, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 113
# Average Fx in the averaging interval [970:1083]: 5.037296234260266
# Average Fz in the averaging interval [970:1083]: 0.48362601401179944
# Maximum Fz in the plotting interval [970:1150]: 1.1339518229166667 at timestep 1079
# Time step where Fx drops below 1: 1083

# %% [markdown]
# <font size="6">Test 5b: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231604.csv"
df = pd.read_csv(data)
test_5b, end_5b = plot_forces(df, cut_1=1206, cut_2=None, avg_end=1875, offset_position='end', offset_length=15, fx_threshold=0.5)
# Out:
# Length from cut_1 to avg_end: 669
# Average Fx in the averaging interval [1206:1875]: 3.9818874979945758
# Average Fz in the averaging interval [1206:1875]: 1.462850153856035
# Maximum Fz in the plotting interval [1206:None]: 2.8288330078125 at timestep 1846
# Time step where Fx drops below 0.5: 1875

# %% [markdown]
# <font size="6">Test 6: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231606.csv"
df = pd.read_csv(data)
test_6, end_6 = plot_forces(df, cut_1=1265, cut_2=None, avg_end=1733, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 468
# Average Fx in the averaging interval [1265:1733]: 5.291862081054949
# Average Fz in the averaging interval [1265:1733]: 1.480090827615852
# Maximum Fz in the plotting interval [1265:None]: 3.0788818359375 at timestep 1720
# Time step where Fx drops below 1: 1733

# %% [markdown]
# <font size="6">Test 7: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231611.csv"
df = pd.read_csv(data)
test_7, end_7 = plot_forces(df, cut_1=550, cut_2=1435, avg_end=1381, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 831
# Average Fx in the averaging interval [550:1381]: 5.4718092599930745
# Average Fz in the averaging interval [550:1381]: 2.173515795398992
# Maximum Fz in the plotting interval [550:1435]: 4.600907389322916 at timestep 1357
# Time step where Fx drops below 1: 1381

# %% [markdown]
# <font size="6">Test 8a: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231617.csv"
df = pd.read_csv(data)
test_8a, end_8a = plot_forces(df, cut_1=370, cut_2=740, avg_end=732, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 362
# Average Fx in the averaging interval [370:732]: 5.505869219623658
# Average Fz in the averaging interval [370:732]: 0.4865432992165917
# Maximum Fz in the plotting interval [370:740]: 1.2226318359375 at timestep 724
# Time step where Fx drops below 1: 732

# %% [markdown]
# <font size="6">Test 8b: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231617.csv"
df = pd.read_csv(data)
test_8b, end_8b = plot_forces(df, cut_1=900, cut_2=None, avg_end=2329, offset_position='end', offset_length=15, fx_threshold=0.2)
# Out:
# Length from cut_1 to avg_end: 1429
# Average Fx in the averaging interval [900:2329]: 2.7705817566180473
# Average Fz in the averaging interval [900:2329]: 2.2039267602043604
# Maximum Fz in the plotting interval [900:None]: 4.8129638671875 at timestep 2272
# Time step where Fx drops below 0.2: 2329

# %% [markdown]
# <font size="6">Test 9: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231621.csv"
df = pd.read_csv(data)
test_9, end_9 = plot_forces(df, cut_1=950, cut_2=None, avg_end=2336, offset_position='end', offset_length=15, fx_threshold=1)
# Out:
# Length from cut_1 to avg_end: 1386
# Average Fx in the averaging interval [950:2336]: 3.5217094148220265
# Average Fz in the averaging interval [950:2336]: 3.296478843964196
# Maximum Fz in the plotting interval [950:None]: 6.423502604166667 at timestep 2320
# Time step where Fx drops below 1: 2336

# %% [markdown]
# <font size="6">Test 10: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_50_5N//log_202405231626.csv"
df = pd.read_csv(data)
test_10, end_10 = plot_forces(df, cut_1=520, cut_2=None, avg_end=1618, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 1098
# Average Fx in the averaging interval [520:1618]: 3.7709570295823727
# Average Fz in the averaging interval [520:1618]: 2.4750848377554355
# Maximum Fz in the plotting interval [520:None]: 4.774788411458333 at timestep 1498
# Time step where Fx drops below 1: 1618

# %%
def plot_multiple_tests(tests, ends):
    # Find the maximum length among all datasets
    max_length = max([end for end in ends if end is not None])
    
    plt.figure(figsize=(15, 7))
    
    for i, (test, end) in enumerate(zip(tests, ends)):
        if end is not None:
            fz_series = test['Fz']
            fz_series_cut = fz_series[:end]
            if len(fz_series_cut) < max_length:
                padded_fz = np.pad(fz_series_cut.values, (0, max_length - len(fz_series_cut)), 'constant', constant_values=np.nan)
            else:
                padded_fz = fz_series_cut.values
            plt.plot(padded_fz, label=f'Dataset {i+1} Fz', alpha=0.6)
        
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Normal Force (Fz) (N)')
    plt.legend()
    plt.title('Normal Force (Fz) of Multiple Datasets')
    plt.grid()
    plt.show()

# %%
tests = [test_1, test_2, test_3, test_4, test_5a, test_5b, test_6, test_7, test_8a, test_8b, test_9, test_10]
ends = [end_1, end_2, end_3, end_4, end_5a, end_5b, end_6, end_7, end_8a, end_8b, end_9, end_10]
plot_multiple_tests(tests, ends)
