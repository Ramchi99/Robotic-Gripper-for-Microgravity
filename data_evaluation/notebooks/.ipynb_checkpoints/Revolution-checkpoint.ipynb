# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mean
from statistics import std

# %%
Se_1 = 4.525716145833333
Se_2 = 5.08624267578125
Se_3 = 0.21867675781249996 #failed

Sc_1 = 2.7895263671875
Sc_2 = 7.426741536458334
Sc_3 = 2.0277669270833334

Ma_1 = 7.116259765625
Ma_2 = 5.465987141927084
Ma_3 = 3.70767822265625

La_1 = 9.1058837890625
La_2 = 4.036263020833333
La_3 = 8.7626220703125

Ka_1 = 5.145491536458334
Ka_2 = 10.275406901041666
Ka_3 = 6.96038818359375

As_1 = 5.861751302083333
As_2 = 1.41085205078125
As_3 = 2.790901692708333

# %%
Array = [Se_1, Se_2, Se_3, Sc_1, Sc_2, Sc_3, Ma_1, Ma_2, Ma_3, La_1, La_2, La_3, Ka_1, Ka_2, Ka_3, As_1, As_2, As_3]

# %%
avg_combined = mean(Array)
std_combined = std(Array)

print(avg_combined)
# Out:
# 5.150786449291088
