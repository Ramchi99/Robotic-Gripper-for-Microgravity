# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_forces(df, cut_1=0, cut_2=None, avg_end=None, fx_threshold=1, offset_position='beginning', offset_length=10):
    """
    Plots the Tangential Force (Fx) and Normal Force (Fz) from the given DataFrame with offsets
    and within a specified range.

    Parameters:
    df (pd.DataFrame): The DataFrame containing force data with columns 'Fx' and 'Fz'.
    cut_1 (int): The starting index for the range of data to be plotted.
    cut_2 (int or None): The ending index for the range of data to be plotted. If None, plot till the end.

    Returns:
    None
    """
    if offset_position == 'beginning':
        # Calculate the offsets as the average of the first 20 entries
        offset_x = df['Fx'][:offset_length].mean()
        offset_z = df['Fz'][:offset_length].mean()
    elif offset_position == 'end':
        # Calculate the offsets as the average of the last 20 entries
        offset_x = df['Fx'][-offset_length:].mean()
        offset_z = df['Fz'][-offset_length:].mean()
    else:
        raise ValueError("Invalid offset_position. Choose either 'beginning' or 'end'.")

    # If avg_end is not provided, use cut_2
    avg_end = avg_end if avg_end is not None else cut_2

    # If avg_end is not None, calculate the length from cut_1 to avg_end
    if avg_end is not None and cut_1 is not None:
        length_cut_to_avg = avg_end - cut_1
        print(f"Length from cut_1 to avg_end: {length_cut_to_avg}")

    # Calculate average values of Fx and Fz in the defined averaging interval
    avg_fx = df[cut_1:avg_end]['Fx'].mean() - offset_x
    avg_fz = df[cut_1:avg_end]['Fz'].mean() - offset_z

    # Apply the cut range to the DataFrame
    df_cut = df[cut_1:cut_2].copy()
    
    # Find the maximum Fz and corresponding timestep
    max_fz = df_cut['Fz'].max() - offset_z
    max_fz_timestep = df_cut['Fz'].idxmax()

    # Find the timestep where Fx drops below the threshold
    fx_drop_timestep = df_cut[df_cut['Fx'] - offset_x < fx_threshold].index.min()
    
    # Print the average values
    print(f"Average Fx in the averaging interval [{cut_1}:{avg_end}]: {avg_fx}")
    print(f"Average Fz in the averaging interval [{cut_1}:{avg_end}]: {avg_fz}")
    print(f"Maximum Fz in the plotting interval [{cut_1}:{cut_2}]: {max_fz} at timestep {max_fz_timestep}")
    print(f"Time step where Fx drops below {fx_threshold}: {fx_drop_timestep}")
    
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'] - offset_x, label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'] - offset_z, label='Normal Force (Fz)', alpha=0.7)
    plt.axvline(x=max_fz_timestep, color='r', linestyle='--', label='Max Fz', alpha=0.2)
    plt.axvline(x=fx_drop_timestep, color='g', linestyle='--', label=f'Fx < {fx_threshold}', alpha=0.2)
    plt.xlabel('Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Tangential vs Normal Force (Offset Adjusted)')
    plt.grid()
    plt.show()

    # Apply the offsets to the cut DataFrame
    df_cut['Fx'] = df_cut['Fx'] - offset_x
    df_cut['Fz'] = df_cut['Fz'] - offset_z
    
    # Shift the index so it starts at 0 if cut_1 is not None
    if cut_1 is not None:
        df_cut.index = df_cut.index - cut_1

    # Return the modified DataFrame
    return df_cut, (length_cut_to_avg if avg_end is not None and cut_1 is not None else None)

# %% [markdown]
# <font size="6">Lavarock 80°</font>

# %% [markdown]
# <font size="6">Test 1: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211741.csv"
df = pd.read_csv(data)
test_1, end_1 = plot_forces(df, cut_1=300, cut_2=861, avg_end=841, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 541
# Average Fx in the averaging interval [300:841]: 5.432358082532148
# Average Fz in the averaging interval [300:841]: 0.8763956329665357
# Maximum Fz in the plotting interval [300:861]: 1.7092000325520833 at timestep 817
# Time step where Fx drops below 1: 841

# %% [markdown]
# <font size="6">Test 2: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211743.csv"
df = pd.read_csv(data)
test_2, end_2 = plot_forces(df, cut_1=1410, cut_2=1620, avg_end=1574, offset_position='end', offset_length=100)
# Out:
# Length from cut_1 to avg_end: 164
# Average Fx in the averaging interval [1410:1574]: 5.717261785530463
# Average Fz in the averaging interval [1410:1574]: 0.356685791015625
# Maximum Fz in the plotting interval [1410:1620]: 0.8933984375 at timestep 1569
# Time step where Fx drops below 1: 1574

# %% [markdown]
# <font size="6">Test 3: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211745.csv"
df = pd.read_csv(data)
test_3, end_3 = plot_forces(df, cut_1=683, cut_2=None, avg_end=1502, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 819
# Average Fx in the averaging interval [683:1502]: 5.83256009291671
# Average Fz in the averaging interval [683:1502]: 1.411102302374275
# Maximum Fz in the plotting interval [683:None]: 2.845076497395833 at timestep 1487
# Time step where Fx drops below 1: 1502

# %% [markdown]
# <font size="6">Test 4: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211748.csv"
df = pd.read_csv(data)
test_4, end_4 = plot_forces(df, cut_1=1340, cut_2=None, avg_end=1548, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 208
# Average Fx in the averaging interval [1340:1548]: 5.731483207146327
# Average Fz in the averaging interval [1340:1548]: 0.5407441750550881
# Maximum Fz in the plotting interval [1340:None]: 1.1972981770833333 at timestep 1542
# Time step where Fx drops below 1: 1548

# %% [markdown]
# <font size="6">Test 5: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211750.csv"
df = pd.read_csv(data)
test_5, end_5 = plot_forces(df, cut_1=970, cut_2=None, avg_end=1443, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 473
# Average Fx in the averaging interval [970:1443]: 5.169240666981564
# Average Fz in the averaging interval [970:1443]: 1.1931607161045412
# Maximum Fz in the plotting interval [970:None]: 2.5795857747395834 at timestep 1416
# Time step where Fx drops below 1: 1443

# %% [markdown]
# <font size="6">Test 6: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211753.csv"
df = pd.read_csv(data)
test_6, end_6 = plot_forces(df, cut_1=730, cut_2=None, avg_end=1197, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 467
# Average Fx in the averaging interval [730:1197]: 4.954019635749833
# Average Fz in the averaging interval [730:1197]: 0.5136114061942363
# Maximum Fz in the plotting interval [730:None]: 1.5614420572916667 at timestep 1116
# Time step where Fx drops below 1: 1197

# %% [markdown]
# <font size="6">Test 7: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211754.csv"
df = pd.read_csv(data)
test_7, end_7 = plot_forces(df, cut_1=1080, cut_2=None, avg_end=1895, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 815
# Average Fx in the averaging interval [1080:1895]: 6.057869731575433
# Average Fz in the averaging interval [1080:1895]: 1.626502038998594
# Maximum Fz in the plotting interval [1080:None]: 3.2198445638020834 at timestep 1879
# Time step where Fx drops below 1: 1895

# %% [markdown]
# <font size="6">Test 8: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211756.csv"
df = pd.read_csv(data)
test_8, end_8 = plot_forces(df, cut_1=837, cut_2=None, avg_end=1879, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 1042
# Average Fx in the averaging interval [837:1879]: 6.227819577715599
# Average Fz in the averaging interval [837:1879]: 1.9051865785761055
# Maximum Fz in the plotting interval [837:None]: 3.7476643880208336 at timestep 1840
# Time step where Fx drops below 1: 1879

# %% [markdown]
# <font size="6">Test 9: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211758.csv"
df = pd.read_csv(data)
test_9, end_9 = plot_forces(df, cut_1=745, cut_2=None, avg_end=1537, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 792
# Average Fx in the averaging interval [745:1537]: 5.992848937800436
# Average Fz in the averaging interval [745:1537]: 1.1814039288145124
# Maximum Fz in the plotting interval [745:None]: 2.1779459635416667 at timestep 1516
# Time step where Fx drops below 1: 1537

# %% [markdown]
# <font size="6">Test 10a: (partially worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211801.csv"
df = pd.read_csv(data)
test_10a, end_10a = plot_forces(df, cut_1=840, cut_2=980, avg_end=965, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 125
# Average Fx in the averaging interval [840:965]: 5.613015137990316
# Average Fz in the averaging interval [840:965]: 0.2776027018229167
# Maximum Fz in the plotting interval [840:980]: 0.6594889322916667 at timestep 921
# Time step where Fx drops below 1: 965

# %% [markdown]
# <font size="6">Test 10b: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_80_5N//log_202405211801.csv"
df = pd.read_csv(data)
test_10b, end_10b = plot_forces(df, cut_1=1331, cut_2=None, avg_end=1979, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 648
# Average Fx in the averaging interval [1331:1979]: 6.016347186359359
# Average Fz in the averaging interval [1331:1979]: 1.2727881725923513
# Maximum Fz in the plotting interval [1331:None]: 2.8708536783854166 at timestep 1968
# Time step where Fx drops below 1: 1979

# %%
def plot_multiple_tests(tests, ends):
    # Find the maximum length among all datasets
    max_length = max([end for end in ends if end is not None])
    
    plt.figure(figsize=(15, 7))
    
    for i, (test, end) in enumerate(zip(tests, ends)):
        if end is not None:
            fz_series = test['Fz']
            fz_series_cut = fz_series[:end]
            if len(fz_series_cut) < max_length:
                padded_fz = np.pad(fz_series_cut.values, (0, max_length - len(fz_series_cut)), 'constant', constant_values=np.nan)
            else:
                padded_fz = fz_series_cut.values
            plt.plot(padded_fz, label=f'Dataset {i+1} Fz', alpha=0.6)
        
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Normal Force (Fz) (N)')
    plt.legend()
    plt.title('Normal Force (Fz) of Multiple Datasets')
    plt.grid()
    plt.show()

# %%
tests = [test_1, test_2, test_3, test_4, test_5, test_6, test_7, test_8, test_9, test_10a, test_10b]
ends = [end_1, end_2, end_3, end_4, end_5, end_6, end_7, end_8, end_9, end_10a, end_10b]
plot_multiple_tests(tests, ends)
