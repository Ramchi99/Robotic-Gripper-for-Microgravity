# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_forces(df, cut_1=0, cut_2=None, avg_end=None, fx_threshold=1, offset_position='beginning', offset_length=10):
    """
    Plots the Tangential Force (Fx) and Normal Force (Fz) from the given DataFrame with offsets
    and within a specified range.

    Parameters:
    df (pd.DataFrame): The DataFrame containing force data with columns 'Fx' and 'Fz'.
    cut_1 (int): The starting index for the range of data to be plotted.
    cut_2 (int or None): The ending index for the range of data to be plotted. If None, plot till the end.

    Returns:
    None
    """
    if offset_position == 'beginning':
        # Calculate the offsets as the average of the first 20 entries
        offset_x = df['Fx'][:offset_length].mean()
        offset_z = df['Fz'][:offset_length].mean()
    elif offset_position == 'end':
        # Calculate the offsets as the average of the last 20 entries
        offset_x = df['Fx'][-offset_length:].mean()
        offset_z = df['Fz'][-offset_length:].mean()
    else:
        raise ValueError("Invalid offset_position. Choose either 'beginning' or 'end'.")

    # If avg_end is not provided, use cut_2
    avg_end = avg_end if avg_end is not None else cut_2

    # If avg_end is not None, calculate the length from cut_1 to avg_end
    if avg_end is not None and cut_1 is not None:
        length_cut_to_avg = avg_end - cut_1
        print(f"Length from cut_1 to avg_end: {length_cut_to_avg}")

    # Calculate average values of Fx and Fz in the defined averaging interval
    avg_fx = df[cut_1:avg_end]['Fx'].mean() - offset_x
    avg_fz = df[cut_1:avg_end]['Fz'].mean() - offset_z

    # Apply the cut range to the DataFrame
    df_cut = df[cut_1:cut_2].copy()
    
    # Find the maximum Fz and corresponding timestep
    max_fz = df_cut['Fz'].max() - offset_z
    max_fz_timestep = df_cut['Fz'].idxmax()

    # Find the timestep where Fx drops below the threshold
    fx_drop_timestep = df_cut[df_cut['Fx'] - offset_x < fx_threshold].index.min()
    
    # Print the average values
    print(f"Average Fx in the averaging interval [{cut_1}:{avg_end}]: {avg_fx}")
    print(f"Average Fz in the averaging interval [{cut_1}:{avg_end}]: {avg_fz}")
    print(f"Maximum Fz in the plotting interval [{cut_1}:{cut_2}]: {max_fz} at timestep {max_fz_timestep}")
    print(f"Time step where Fx drops below {fx_threshold}: {fx_drop_timestep}")
    
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'] - offset_x, label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'] - offset_z, label='Normal Force (Fz)', alpha=0.7)
    plt.axvline(x=max_fz_timestep, color='r', linestyle='--', label='Max Fz', alpha=0.2)
    plt.axvline(x=fx_drop_timestep, color='g', linestyle='--', label=f'Fx < {fx_threshold}', alpha=0.2)
    plt.xlabel('Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Tangential vs Normal Force (Offset Adjusted)')
    plt.grid()
    plt.show()

    # Apply the offsets to the cut DataFrame
    df_cut['Fx'] = df_cut['Fx'] - offset_x
    df_cut['Fz'] = df_cut['Fz'] - offset_z
    
    # Shift the index so it starts at 0 if cut_1 is not None
    if cut_1 is not None:
        df_cut.index = df_cut.index - cut_1

    # Return the modified DataFrame
    return df_cut, (length_cut_to_avg if avg_end is not None and cut_1 is not None else None)

# %%
def plot_modified_df(df_cut):
    """
    Plots the modified DataFrame with adjusted time steps.

    Parameters:
    df_cut (pd.DataFrame): The modified DataFrame with adjusted time steps.

    Returns:
    None
    """
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'], label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'], label='Normal Force (Fz)', alpha=0.7)
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Modified Tangential vs Normal Force (Adjusted Timesteps)')
    plt.grid()
    plt.show()

# %% [markdown]
# <font size="6">Sediment 90°</font>

# %% [markdown]
# <font size="6">Test 1: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Sediment_90_5N//log_202405231812.csv"
df = pd.read_csv(data)
test_1, end_1 = plot_forces(df, cut_1=1550, cut_2=None, avg_end=1855, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 305
# Average Fx in the averaging interval [1550:1855]: 5.389202003270551
# Average Fz in the averaging interval [1550:1855]: 0.465060474833504
# Maximum Fz in the plotting interval [1550:None]: 1.05208740234375 at timestep 1763
# Time step where Fx drops below 1: 1855

# %% [markdown]
# <font size="6">Test 2: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Sediment_90_5N//log_202405231815.csv"
df = pd.read_csv(data)
test_2, end_2 = plot_forces(df, cut_1=496, cut_2=None, avg_end=619, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 123
# Average Fx in the averaging interval [496:619]: 3.8229105236084484
# Average Fz in the averaging interval [496:619]: 0.24522318025914636
# Maximum Fz in the plotting interval [496:None]: 0.57447509765625 at timestep 593
# Time step where Fx drops below 1: 619

# %% [markdown]
# <font size="6">Test 3: (failed)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Sediment_90_5N//log_202405231817.csv"
df = pd.read_csv(data)
test_3, end_3 = plot_forces(df, cut_1=None, cut_2=None, avg_end=None, offset_position='beginning', offset_length=15)
# Out:
# Average Fx in the averaging interval [None:None]: 3.4116689259871773
# Average Fz in the averaging interval [None:None]: -0.5138361679011093
# Maximum Fz in the plotting interval [None:None]: 0.2513753255208333 at timestep 684
# Time step where Fx drops below 1: 0

# %% [markdown]
# <font size="6">Test 4: (failed)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Sediment_90_5N//log_202405231818.csv"
df = pd.read_csv(data)
test_4, end_4 = plot_forces(df, cut_1=None, cut_2=None, avg_end=None, offset_position='beginning', offset_length=15)
# Out:
# Average Fx in the averaging interval [None:None]: 2.2275922642952484
# Average Fz in the averaging interval [None:None]: -0.6888856365210515
# Maximum Fz in the plotting interval [None:None]: 0.2015706380208333 at timestep 531
# Time step where Fx drops below 1: 0

# %% [markdown]
# <font size="6">Test 5: (failed)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Sediment_90_5N//log_202405231820.csv"
df = pd.read_csv(data)
test_5, end_5 = plot_forces(df, cut_1=None, cut_2=None, avg_end=None, offset_position='beginning', offset_length=15)
# Out:
# Average Fx in the averaging interval [None:None]: 2.4228450428344037
# Average Fz in the averaging interval [None:None]: -0.7662641067878263
# Maximum Fz in the plotting interval [None:None]: 0.23433837890624998 at timestep 617
# Time step where Fx drops below 1: 0

# %% [markdown]
# <font size="6">Test 6: (failed)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Sediment_90_5N//log_202405231823.csv"
df = pd.read_csv(data)
test_6, end_6 = plot_forces(df, cut_1=None, cut_2=None, avg_end=None, offset_position='beginning', offset_length=15)
# Out:
# Average Fx in the averaging interval [None:None]: 2.092113788494331
# Average Fz in the averaging interval [None:None]: -1.0067911052894212
# Maximum Fz in the plotting interval [None:None]: 0.20830891927083328 at timestep 142
# Time step where Fx drops below 1: 0

# %% [markdown]
# <font size="6">Test 7: (failed)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Sediment_90_5N//log_202405231824.csv"
df = pd.read_csv(data)
test_7, end_7 = plot_forces(df, cut_1=None, cut_2=None, avg_end=None, offset_position='beginning', offset_length=15)
# Out:
# Average Fx in the averaging interval [None:None]: 3.4662255135788462
# Average Fz in the averaging interval [None:None]: -0.4613507445525441
# Maximum Fz in the plotting interval [None:None]: 0.3518351236979167 at timestep 1386
# Time step where Fx drops below 1: 0

# %% [markdown]
# <font size="6">Test 8: (failed / also tangential force)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Sediment_90_5N//log_202405231826.csv"
df = pd.read_csv(data)
test_8, end_8 = plot_forces(df, cut_1=None, cut_2=None, avg_end=None, offset_position='beginning', offset_length=15)
# Out:
# Average Fx in the averaging interval [None:None]: 0.12246276013056434
# Average Fz in the averaging interval [None:None]: -0.2536187133789063
# Maximum Fz in the plotting interval [None:None]: 0.22707519531249998 at timestep 561
# Time step where Fx drops below 1: 0

# %% [markdown]
# <font size="6">Test 9: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Sediment_90_5N//log_202405231827.csv"
df = pd.read_csv(data)
test_9, end_9 = plot_forces(df, cut_1=450, cut_2=None, avg_end=1155, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 705
# Average Fx in the averaging interval [450:1155]: 3.4851687708645005
# Average Fz in the averaging interval [450:1155]: 0.19835586006759753
# Maximum Fz in the plotting interval [450:None]: 0.5132283528645833 at timestep 986
# Time step where Fx drops below 1: 1155

# %% [markdown]
# <font size="6">Test 10: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Sediment_90_5N//log_202405231829.csv"
df = pd.read_csv(data)
test_10, end_10 = plot_forces(df, cut_1=603, cut_2=None, avg_end=1107, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 504
# Average Fx in the averaging interval [603:1107]: 2.1109703930597457
# Average Fz in the averaging interval [603:1107]: 0.485820055764819
# Maximum Fz in the plotting interval [603:None]: 1.1439860026041666 at timestep 1077
# Time step where Fx drops below 1: 1107

# %%
def plot_multiple_tests(tests, ends):
    # Find the maximum length among all datasets
    max_length = max([end for end in ends if end is not None])
    
    plt.figure(figsize=(15, 7))
    
    for i, (test, end) in enumerate(zip(tests, ends)):
        if end is not None:
            fz_series = test['Fz']
            fz_series_cut = fz_series[:end]
            if len(fz_series_cut) < max_length:
                padded_fz = np.pad(fz_series_cut.values, (0, max_length - len(fz_series_cut)), 'constant', constant_values=np.nan)
            else:
                padded_fz = fz_series_cut.values
            plt.plot(padded_fz, label=f'Dataset {i+1} Fz', alpha=0.6)
        
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Normal Force (Fz) (N)')
    plt.legend()
    plt.title('Normal Force (Fz) of Multiple Datasets')
    plt.grid()
    plt.show()

# %%
tests = [test_1, test_2, test_9, test_10]
ends = [end_1, end_2, end_9, end_10]
plot_multiple_tests(tests, ends)
