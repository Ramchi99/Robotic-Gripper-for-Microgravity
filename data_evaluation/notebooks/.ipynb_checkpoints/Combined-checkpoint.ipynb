# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mean

# %%
Se_1 = 2.607963053385417
Se_2 = 3.4246337890625
Se_3 = 7.25103759765625

Sc_1 = 2.15833740234375
Sc_2 = 5.084151204427084
Sc_3 = 7.46185302734375

Ma_1 = 7.317964680989584
Ma_2 = 9.600032552083333
Ma_3 = 3.3965738932291667

La_1 = 2.0090535481770835
La_2 = 7.30826416015625
La_3 = 5.50546875

Ka_1 = 4.125101725260417
Ka_2 = 6.772709147135417
Ka_3 = 7.369283040364583

As_1 = 5.041910807291667
As_2 = 3.0290771484375
As_3 = 6.032743326822916

# %%
Array = [Se_1, Se_2, Se_3, Sc_1, Sc_2, Sc_3, Ma_1, Ma_2, Ma_3, La_1, La_2, La_3, Ka_1, Ka_2, Ka_3, As_1, As_2, As_3]

# %%
avg_combined = mean(Array)

print(avg_combined)
# Out:
# 5.305342158564815
