# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_forces(df, cut_1=0, cut_2=None, avg_end=None, fx_threshold=1, offset_position='beginning', offset_length=10):
    """
    Plots the Tangential Force (Fx) and Normal Force (Fz) from the given DataFrame with offsets
    and within a specified range.

    Parameters:
    df (pd.DataFrame): The DataFrame containing force data with columns 'Fx' and 'Fz'.
    cut_1 (int): The starting index for the range of data to be plotted.
    cut_2 (int or None): The ending index for the range of data to be plotted. If None, plot till the end.

    Returns:
    None
    """
    if offset_position == 'beginning':
        # Calculate the offsets as the average of the first 20 entries
        offset_x = df['Fx'][:offset_length].mean()
        offset_z = df['Fz'][:offset_length].mean()
    elif offset_position == 'end':
        # Calculate the offsets as the average of the last 20 entries
        offset_x = df['Fx'][-offset_length:].mean()
        offset_z = df['Fz'][-offset_length:].mean()
    else:
        raise ValueError("Invalid offset_position. Choose either 'beginning' or 'end'.")

    # If avg_end is not provided, use cut_2
    avg_end = avg_end if avg_end is not None else cut_2

    # If avg_end is not None, calculate the length from cut_1 to avg_end
    if avg_end is not None and cut_1 is not None:
        length_cut_to_avg = avg_end - cut_1
        print(f"Length from cut_1 to avg_end: {length_cut_to_avg}")

    # Calculate average values of Fx and Fz in the defined averaging interval
    avg_fx = df[cut_1:avg_end]['Fx'].mean() - offset_x
    avg_fz = df[cut_1:avg_end]['Fz'].mean() - offset_z

    # Apply the cut range to the DataFrame
    df_cut = df[cut_1:cut_2].copy()
    
    # Find the maximum Fz and corresponding timestep
    max_fz = df_cut['Fz'].max() - offset_z
    max_fz_timestep = df_cut['Fz'].idxmax()

    # Find the timestep where Fx drops below the threshold
    fx_drop_timestep = df_cut[df_cut['Fx'] - offset_x < fx_threshold].index.min()
    
    # Print the average values
    print(f"Average Fx in the averaging interval [{cut_1}:{avg_end}]: {avg_fx}")
    print(f"Average Fz in the averaging interval [{cut_1}:{avg_end}]: {avg_fz}")
    print(f"Maximum Fz in the plotting interval [{cut_1}:{cut_2}]: {max_fz} at timestep {max_fz_timestep}")
    print(f"Time step where Fx drops below {fx_threshold}: {fx_drop_timestep}")
    
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'] - offset_x, label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'] - offset_z, label='Normal Force (Fz)', alpha=0.7)
    plt.axvline(x=max_fz_timestep, color='r', linestyle='--', label='Max Fz', alpha=0.2)
    plt.axvline(x=fx_drop_timestep, color='g', linestyle='--', label=f'Fx < {fx_threshold}', alpha=0.2)
    plt.xlabel('Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Tangential vs Normal Force (Offset Adjusted)')
    plt.grid()
    plt.show()

    # Apply the offsets to the cut DataFrame
    df_cut['Fx'] = df_cut['Fx'] - offset_x
    df_cut['Fz'] = df_cut['Fz'] - offset_z
    
    # Shift the index so it starts at 0 if cut_1 is not None
    if cut_1 is not None:
        df_cut.index = df_cut.index - cut_1

    # Return the modified DataFrame
    return df_cut, (length_cut_to_avg if avg_end is not None and cut_1 is not None else None)

# %%
def plot_modified_df(df_cut):
    """
    Plots the modified DataFrame with adjusted time steps.

    Parameters:
    df_cut (pd.DataFrame): The modified DataFrame with adjusted time steps.

    Returns:
    None
    """
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'], label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'], label='Normal Force (Fz)', alpha=0.7)
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Modified Tangential vs Normal Force (Adjusted Timesteps)')
    plt.grid()
    plt.show()

# %% [markdown]
# <font size="6">Schieferstein 70°</font>

# %% [markdown]
# <font size="6">Test 1: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231909.csv"
df = pd.read_csv(data)
test_1, end_1 = plot_forces(df, cut_1=837, cut_2=None, avg_end=1525, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 688
# Average Fx in the averaging interval [837:1525]: 5.568581696674805
# Average Fz in the averaging interval [837:1525]: 1.10853965226994
# Maximum Fz in the plotting interval [837:None]: 2.16165771484375 at timestep 1469
# Time step where Fx drops below 1: 1525

# %% [markdown]
# <font size="6">Test 2: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231910.csv"
df = pd.read_csv(data)
test_2, end_2 = plot_forces(df, cut_1=1020, cut_2=None, avg_end=1630, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 610
# Average Fx in the averaging interval [1020:1630]: 5.761520016258531
# Average Fz in the averaging interval [1020:1630]: 0.9893933572404372
# Maximum Fz in the plotting interval [1020:None]: 2.3211344401041667 at timestep 1622
# Time step where Fx drops below 1: 1630

# %% [markdown]
# <font size="6">Test 3: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231911.csv"
df = pd.read_csv(data)
test_3, end_3 = plot_forces(df, cut_1=830, cut_2=None, avg_end=1328, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 498
# Average Fx in the averaging interval [830:1328]: 5.543672400018776
# Average Fz in the averaging interval [830:1328]: 0.9087425875376506
# Maximum Fz in the plotting interval [830:None]: 1.6271280924479168 at timestep 1313
# Time step where Fx drops below 1: 1328

# %% [markdown]
# <font size="6">Test 4: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231912.csv"
df = pd.read_csv(data)
test_4, end_4 = plot_forces(df, cut_1=1220, cut_2=None, avg_end=1955, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 735
# Average Fx in the averaging interval [1220:1955]: 5.131965486695166
# Average Fz in the averaging interval [1220:1955]: 1.86129532379358
# Maximum Fz in the plotting interval [1220:None]: 2.959403483072917 at timestep 1925
# Time step where Fx drops below 1: 1955

# %% [markdown]
# <font size="6">Test 5: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231914.csv"
df = pd.read_csv(data)
test_5, end_5 = plot_forces(df, cut_1=1490, cut_2=None, avg_end=2222, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 732
# Average Fx in the averaging interval [1490:2222]: 4.677920339407165
# Average Fz in the averaging interval [1490:2222]: 1.524683867907915
# Maximum Fz in the plotting interval [1490:None]: 3.1150146484375 at timestep 2207
# Time step where Fx drops below 1: 2222

# %% [markdown]
# <font size="6">Test 6a: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231916.csv"
df = pd.read_csv(data)
test_6a, end_6a = plot_forces(df, cut_1=460, cut_2=825, avg_end=807, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 347
# Average Fx in the averaging interval [460:807]: 3.881711969824506
# Average Fz in the averaging interval [460:807]: 0.18436750692318082
# Maximum Fz in the plotting interval [460:825]: 0.6654052734375 at timestep 774
# Time step where Fx drops below 1: 807

# %% [markdown]
# <font size="6">Test 6b: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231916.csv"
df = pd.read_csv(data)
test_6b, end_6b = plot_forces(df, cut_1=831, cut_2=None, avg_end=1152, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 321
# Average Fx in the averaging interval [831:1152]: 3.0023215935609047
# Average Fz in the averaging interval [831:1152]: 0.49038610725759346
# Maximum Fz in the plotting interval [831:None]: 0.96710205078125 at timestep 1145
# Time step where Fx drops below 1: 1152

# %% [markdown]
# <font size="6">Test 7: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231917.csv"
df = pd.read_csv(data)
test_7, end_7 = plot_forces(df, cut_1=895, cut_2=None, avg_end=1219, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 324
# Average Fx in the averaging interval [895:1219]: 5.226406216327055
# Average Fz in the averaging interval [895:1219]: 0.5779635582441165
# Maximum Fz in the plotting interval [895:None]: 1.2980753580729167 at timestep 1199
# Time step where Fx drops below 1: 1219

# %% [markdown]
# <font size="6">Test 8: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231918.csv"
df = pd.read_csv(data)
test_8, end_8 = plot_forces(df, cut_1=880, cut_2=1538, avg_end=1516, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 636
# Average Fx in the averaging interval [880:1516]: 4.8595372132535255
# Average Fz in the averaging interval [880:1516]: 0.9459778791703518
# Maximum Fz in the plotting interval [880:1538]: 2.40133056640625 at timestep 1499
# Time step where Fx drops below 1: 1516

# %% [markdown]
# <font size="6">Test 9: (failed)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231919.csv"
df = pd.read_csv(data)
test_9, end_9 = plot_forces(df, cut_1=None, cut_2=None, avg_end=None, offset_position='beginning', offset_length=20)
# Out:
# Average Fx in the averaging interval [None:None]: 3.8001535675742413
# Average Fz in the averaging interval [None:None]: -0.8419622358842329
# Maximum Fz in the plotting interval [None:None]: 0.3012603759765625 at timestep 1293
# Time step where Fx drops below 1: 0

# %% [markdown]
# <font size="6">Test 10: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_70_5N//log_202405231921.csv"
df = pd.read_csv(data)
test_10, end_10 = plot_forces(df, cut_1=1390, cut_2=1568, avg_end=1546, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 156
# Average Fx in the averaging interval [1390:1546]: 4.078097091576992
# Average Fz in the averaging interval [1390:1546]: 0.37739969889322916
# Maximum Fz in the plotting interval [1390:1568]: 0.8550252278645833 at timestep 1527
# Time step where Fx drops below 1: 1546

# %%
def plot_multiple_tests(tests, ends):
    # Find the maximum length among all datasets
    max_length = max([end for end in ends if end is not None])
    
    plt.figure(figsize=(15, 7))
    
    for i, (test, end) in enumerate(zip(tests, ends)):
        if end is not None:
            fz_series = test['Fz']
            fz_series_cut = fz_series[:end]
            if len(fz_series_cut) < max_length:
                padded_fz = np.pad(fz_series_cut.values, (0, max_length - len(fz_series_cut)), 'constant', constant_values=np.nan)
            else:
                padded_fz = fz_series_cut.values
            plt.plot(padded_fz, label=f'Dataset {i+1} Fz', alpha=0.6)
        
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Normal Force (Fz) (N)')
    plt.legend()
    plt.title('Normal Force (Fz) of Multiple Datasets')
    plt.grid()
    plt.show()

# %%
tests = [test_1, test_2, test_3, test_4, test_5, test_6a, test_6b, test_7, test_8, test_10]
ends = [end_1, end_2, end_3, end_4, end_5, end_6a, end_6b, end_7, end_8, end_10]
plot_multiple_tests(tests, ends)
