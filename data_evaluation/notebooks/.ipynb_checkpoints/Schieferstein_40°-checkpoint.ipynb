# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_forces(df, cut_1=0, cut_2=None, avg_end=None, fx_threshold=1, offset_position='beginning', offset_length=10):
    """
    Plots the Tangential Force (Fx) and Normal Force (Fz) from the given DataFrame with offsets
    and within a specified range.

    Parameters:
    df (pd.DataFrame): The DataFrame containing force data with columns 'Fx' and 'Fz'.
    cut_1 (int): The starting index for the range of data to be plotted.
    cut_2 (int or None): The ending index for the range of data to be plotted. If None, plot till the end.

    Returns:
    None
    """
    if offset_position == 'beginning':
        # Calculate the offsets as the average of the first 20 entries
        offset_x = df['Fx'][:offset_length].mean()
        offset_z = df['Fz'][:offset_length].mean()
    elif offset_position == 'end':
        # Calculate the offsets as the average of the last 20 entries
        offset_x = df['Fx'][-offset_length:].mean()
        offset_z = df['Fz'][-offset_length:].mean()
    else:
        raise ValueError("Invalid offset_position. Choose either 'beginning' or 'end'.")

    # If avg_end is not provided, use cut_2
    avg_end = avg_end if avg_end is not None else cut_2

    # If avg_end is not None, calculate the length from cut_1 to avg_end
    if avg_end is not None and cut_1 is not None:
        length_cut_to_avg = avg_end - cut_1
        print(f"Length from cut_1 to avg_end: {length_cut_to_avg}")

    # Calculate average values of Fx and Fz in the defined averaging interval
    avg_fx = df[cut_1:avg_end]['Fx'].mean() - offset_x
    avg_fz = df[cut_1:avg_end]['Fz'].mean() - offset_z

    # Apply the cut range to the DataFrame
    df_cut = df[cut_1:cut_2].copy()
    
    # Find the maximum Fz and corresponding timestep
    max_fz = df_cut['Fz'].max() - offset_z
    max_fz_timestep = df_cut['Fz'].idxmax()

    # Find the timestep where Fx drops below the threshold
    fx_drop_timestep = df_cut[df_cut['Fx'] - offset_x < fx_threshold].index.min()
    
    # Print the average values
    print(f"Average Fx in the averaging interval [{cut_1}:{avg_end}]: {avg_fx}")
    print(f"Average Fz in the averaging interval [{cut_1}:{avg_end}]: {avg_fz}")
    print(f"Maximum Fz in the plotting interval [{cut_1}:{cut_2}]: {max_fz} at timestep {max_fz_timestep}")
    print(f"Time step where Fx drops below {fx_threshold}: {fx_drop_timestep}")
    
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'] - offset_x, label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'] - offset_z, label='Normal Force (Fz)', alpha=0.7)
    plt.axvline(x=max_fz_timestep, color='r', linestyle='--', label='Max Fz', alpha=0.2)
    plt.axvline(x=fx_drop_timestep, color='g', linestyle='--', label=f'Fx < {fx_threshold}', alpha=0.2)
    plt.xlabel('Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Tangential vs Normal Force (Offset Adjusted)')
    plt.grid()
    plt.show()

    # Apply the offsets to the cut DataFrame
    df_cut['Fx'] = df_cut['Fx'] - offset_x
    df_cut['Fz'] = df_cut['Fz'] - offset_z
    
    # Shift the index so it starts at 0 if cut_1 is not None
    if cut_1 is not None:
        df_cut.index = df_cut.index - cut_1

    # Return the modified DataFrame
    return df_cut, (length_cut_to_avg if avg_end is not None and cut_1 is not None else None)

# %%
def plot_modified_df(df_cut):
    """
    Plots the modified DataFrame with adjusted time steps.

    Parameters:
    df_cut (pd.DataFrame): The modified DataFrame with adjusted time steps.

    Returns:
    None
    """
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'], label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'], label='Normal Force (Fz)', alpha=0.7)
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Modified Tangential vs Normal Force (Adjusted Timesteps)')
    plt.grid()
    plt.show()

# %% [markdown]
# <font size="6">Schieferstein 40°</font>

# %% [markdown]
# <font size="6">Test 1a: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240852.csv"
df = pd.read_csv(data)
test_1a, end_1a = plot_forces(df, cut_1=690, cut_2=1270, avg_end=1201, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 511
# Average Fx in the averaging interval [690:1201]: 5.473804552634402
# Average Fz in the averaging interval [690:1201]: 1.1759323528212655
# Maximum Fz in the plotting interval [690:1270]: 2.5203898111979166 at timestep 1178
# Time step where Fx drops below 1: 1202

# %% [markdown]
# <font size="6">Test 1b: (worked (kind of))</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240852.csv"
df = pd.read_csv(data)
test_1b, end_1b = plot_forces(df, cut_1=1680, cut_2=1987, avg_end=None, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 307
# Average Fx in the averaging interval [1680:1987]: 4.308913597920819
# Average Fz in the averaging interval [1680:1987]: 0.5577194694328516
# Maximum Fz in the plotting interval [1680:1987]: 1.1871378580729166 at timestep 1984
# Time step where Fx drops below 1: nan

# %% [markdown]
# <font size="6">Test 2: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240854.csv"
df = pd.read_csv(data)
test_2, end_2 = plot_forces(df, cut_1=190, cut_2=None, avg_end=2009, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 1819
# Average Fx in the averaging interval [190:2009]: 4.8684563978526185
# Average Fz in the averaging interval [190:2009]: 3.1936366828693363
# Maximum Fz in the plotting interval [190:None]: 7.039908854166667 at timestep 1935
# Time step where Fx drops below 1: 2009

# %% [markdown]
# <font size="6">Test 3: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240857.csv"
df = pd.read_csv(data)
test_3, end_3 = plot_forces(df, cut_1=1200, cut_2=None, avg_end=2200, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 1000
# Average Fx in the averaging interval [1200:2200]: 3.187931460618973
# Average Fz in the averaging interval [1200:2200]: 1.6840720011393229
# Maximum Fz in the plotting interval [1200:None]: 3.790763346354167 at timestep 2171
# Time step where Fx drops below 1: 2200

# %% [markdown]
# <font size="6">Test 4: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240859.csv"
df = pd.read_csv(data)
test_4, end_4 = plot_forces(df, cut_1=456, cut_2=None, avg_end=1503, offset_position='end', offset_length=15, fx_threshold=0.0)
# Out:
# Length from cut_1 to avg_end: 1047
# Average Fx in the averaging interval [456:1503]: 4.911778501567094
# Average Fz in the averaging interval [456:1503]: 2.3899380601010325
# Maximum Fz in the plotting interval [456:None]: 4.34366455078125 at timestep 1466
# Time step where Fx drops below 0.0: 1506

# %% [markdown]
# <font size="6">Test 5: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240900.csv"
df = pd.read_csv(data)
test_5, end_5 = plot_forces(df, cut_1=750, cut_2=None, avg_end=1450, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 700
# Average Fx in the averaging interval [750:1450]: 5.243585344723293
# Average Fz in the averaging interval [750:1450]: 1.9738188534691217
# Maximum Fz in the plotting interval [750:None]: 3.4809977213541665 at timestep 1331
# Time step where Fx drops below 1: 1450

# %% [markdown]
# <font size="6">Test 6: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240902.csv"
df = pd.read_csv(data)
test_6, end_6 = plot_forces(df, cut_1=124, cut_2=None, avg_end=1712, offset_position='end', offset_length=30)
# Out:
# Length from cut_1 to avg_end: 1588
# Average Fx in the averaging interval [124:1712]: 4.563187433159921
# Average Fz in the averaging interval [124:1712]: 2.198921737863075
# Maximum Fz in the plotting interval [124:None]: 5.516650390625 at timestep 1667
# Time step where Fx drops below 1: 124

# %% [markdown]
# <font size="6">Test 7: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240903.csv"
df = pd.read_csv(data)
test_7, end_7 = plot_forces(df, cut_1=750, cut_2=None, avg_end=1604, offset_position='end', offset_length=30)
# Out:
# Length from cut_1 to avg_end: 854
# Average Fx in the averaging interval [750:1604]: 4.596733006027692
# Average Fz in the averaging interval [750:1604]: 2.2227298924180325
# Maximum Fz in the plotting interval [750:None]: 4.769354248046875 at timestep 1575
# Time step where Fx drops below 1: 1604

# %% [markdown]
# <font size="6">Test 8: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240905.csv"
df = pd.read_csv(data)
test_8, end_8 = plot_forces(df, cut_1=491, cut_2=None, avg_end=1195, offset_position='end', offset_length=30)
# Out:
# Length from cut_1 to avg_end: 704
# Average Fx in the averaging interval [491:1195]: 5.207492732392116
# Average Fz in the averaging interval [491:1195]: 1.6628956245653557
# Maximum Fz in the plotting interval [491:None]: 4.295296223958333 at timestep 1193
# Time step where Fx drops below 1: 1195

# %% [markdown]
# <font size="6">Test 9: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240943.csv"
df = pd.read_csv(data)
test_9, end_9 = plot_forces(df, cut_1=61, cut_2=651, avg_end=638, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 577
# Average Fx in the averaging interval [61:638]: 3.7074405436017206
# Average Fz in the averaging interval [61:638]: 0.8665345542903308
# Maximum Fz in the plotting interval [61:651]: 1.7057088216145833 at timestep 568
# Time step where Fx drops below 1: 118

# %% [markdown]
# <font size="6">Test 10: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_40_5N//log_202405240945.csv"
df = pd.read_csv(data)
test_10, end_10 = plot_forces(df, cut_1=390, cut_2=None, avg_end=991, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 601
# Average Fx in the averaging interval [390:991]: 3.022380972939997
# Average Fz in the averaging interval [390:991]: 0.8027779696057785
# Maximum Fz in the plotting interval [390:None]: 2.087052408854167 at timestep 961
# Time step where Fx drops below 1: 991

# %%
def plot_multiple_tests(tests, ends):
    # Find the maximum length among all datasets
    max_length = max([end for end in ends if end is not None])
    
    plt.figure(figsize=(15, 7))
    
    for i, (test, end) in enumerate(zip(tests, ends)):
        if end is not None:
            fz_series = test['Fz']
            fz_series_cut = fz_series[:end]
            if len(fz_series_cut) < max_length:
                padded_fz = np.pad(fz_series_cut.values, (0, max_length - len(fz_series_cut)), 'constant', constant_values=np.nan)
            else:
                padded_fz = fz_series_cut.values
            plt.plot(padded_fz, label=f'Dataset {i+1} Fz', alpha=0.6)
        
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Normal Force (Fz) (N)')
    plt.legend()
    plt.title('Normal Force (Fz) of Multiple Datasets')
    plt.grid()
    plt.show()

# %%
tests = [test_1a, test_1b, test_2, test_3, test_4, test_5, test_6, test_7, test_8, test_9, test_10]
ends = [end_1a, end_1b, end_2, end_3, end_4, end_5, end_6, end_7, end_8, end_9, end_10]
plot_multiple_tests(tests, ends)
