# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_forces(df, cut_1=0, cut_2=None, avg_end=None, fx_threshold=1, offset_position='beginning', offset_length=10):
    """
    Plots the Tangential Force (Fx) and Normal Force (Fz) from the given DataFrame with offsets
    and within a specified range.

    Parameters:
    df (pd.DataFrame): The DataFrame containing force data with columns 'Fx' and 'Fz'.
    cut_1 (int): The starting index for the range of data to be plotted.
    cut_2 (int or None): The ending index for the range of data to be plotted. If None, plot till the end.

    Returns:
    None
    """
    if offset_position == 'beginning':
        # Calculate the offsets as the average of the first 20 entries
        offset_x = df['Fx'][:offset_length].mean()
        offset_z = df['Fz'][:offset_length].mean()
    elif offset_position == 'end':
        # Calculate the offsets as the average of the last 20 entries
        offset_x = df['Fx'][-offset_length:].mean()
        offset_z = df['Fz'][-offset_length:].mean()
    else:
        raise ValueError("Invalid offset_position. Choose either 'beginning' or 'end'.")

    # If avg_end is not provided, use cut_2
    avg_end = avg_end if avg_end is not None else cut_2

    # If avg_end is not None, calculate the length from cut_1 to avg_end
    if avg_end is not None and cut_1 is not None:
        length_cut_to_avg = avg_end - cut_1
        print(f"Length from cut_1 to avg_end: {length_cut_to_avg}")

    # Calculate average values of Fx and Fz in the defined averaging interval
    avg_fx = df[cut_1:avg_end]['Fx'].mean() - offset_x
    avg_fz = df[cut_1:avg_end]['Fz'].mean() - offset_z

    # Apply the cut range to the DataFrame
    df_cut = df[cut_1:cut_2].copy()
    
    # Find the maximum Fz and corresponding timestep
    max_fz = df_cut['Fz'].max() - offset_z
    max_fz_timestep = df_cut['Fz'].idxmax()

    # Find the timestep where Fx drops below the threshold
    fx_drop_timestep = df_cut[df_cut['Fx'] - offset_x < fx_threshold].index.min()
    
    # Print the average values
    print(f"Average Fx in the averaging interval [{cut_1}:{avg_end}]: {avg_fx}")
    print(f"Average Fz in the averaging interval [{cut_1}:{avg_end}]: {avg_fz}")
    print(f"Maximum Fz in the plotting interval [{cut_1}:{cut_2}]: {max_fz} at timestep {max_fz_timestep}")
    print(f"Time step where Fx drops below {fx_threshold}: {fx_drop_timestep}")
    
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'] - offset_x, label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'] - offset_z, label='Normal Force (Fz)', alpha=0.7)
    plt.axvline(x=max_fz_timestep, color='r', linestyle='--', label='Max Fz', alpha=0.2)
    plt.axvline(x=fx_drop_timestep, color='g', linestyle='--', label=f'Fx < {fx_threshold}', alpha=0.2)
    plt.xlabel('Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Tangential vs Normal Force (Offset Adjusted)')
    plt.grid()
    plt.show()

    # Apply the offsets to the cut DataFrame
    df_cut['Fx'] = df_cut['Fx'] - offset_x
    df_cut['Fz'] = df_cut['Fz'] - offset_z
    
    # Shift the index so it starts at 0 if cut_1 is not None
    if cut_1 is not None:
        df_cut.index = df_cut.index - cut_1

    # Return the modified DataFrame
    return df_cut, (length_cut_to_avg if avg_end is not None and cut_1 is not None else None)

# %%
def plot_modified_df(df_cut):
    """
    Plots the modified DataFrame with adjusted time steps.

    Parameters:
    df_cut (pd.DataFrame): The modified DataFrame with adjusted time steps.

    Returns:
    None
    """
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'], label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'], label='Normal Force (Fz)', alpha=0.7)
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Modified Tangential vs Normal Force (Adjusted Timesteps)')
    plt.grid()
    plt.show()

# %% [markdown]
# <font size="6">Schieferstein 80°</font>

# %% [markdown]
# <font size="6">Test 1: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241742.csv"
df = pd.read_csv(data)
test_1, end_1 = plot_forces(df, cut_1=700, cut_2=None, avg_end=1336, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 636
# Average Fx in the averaging interval [700:1336]: 5.391043791980864
# Average Fz in the averaging interval [700:1336]: 0.8312892697892099
# Maximum Fz in the plotting interval [700:None]: 1.7949259440104166 at timestep 1305
# Time step where Fx drops below 1: 1336

# %% [markdown]
# <font size="6">Test 2: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241744.csv"
df = pd.read_csv(data)
test_2, end_2 = plot_forces(df, cut_1=750, cut_2=None, avg_end=1148, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 398
# Average Fx in the averaging interval [750:1148]: 6.096339598452825
# Average Fz in the averaging interval [750:1148]: 0.23061897622880023
# Maximum Fz in the plotting interval [750:None]: 0.80543212890625 at timestep 1137
# Time step where Fx drops below 1: 1148

# %% [markdown]
# <font size="6">Test 3: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241745.csv"
df = pd.read_csv(data)
test_3, end_3 = plot_forces(df, cut_1=885, cut_2=None, avg_end=1391, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 506
# Average Fx in the averaging interval [885:1391]: 5.496351951666972
# Average Fz in the averaging interval [885:1391]: 1.2000385832252554
# Maximum Fz in the plotting interval [885:None]: 2.2157796223958335 at timestep 1372
# Time step where Fx drops below 1: 1391

# %% [markdown]
# <font size="6">Test 4: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241746.csv"
df = pd.read_csv(data)
test_4, end_4 = plot_forces(df, cut_1=440, cut_2=None, avg_end=890, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 450
# Average Fx in the averaging interval [440:890]: 5.284594776365492
# Average Fz in the averaging interval [440:890]: 0.47672214084201386
# Maximum Fz in the plotting interval [440:None]: 1.10872802734375 at timestep 886
# Time step where Fx drops below 1: 890

# %% [markdown]
# <font size="6">Test 5: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241747.csv"
df = pd.read_csv(data)
test_5, end_5 = plot_forces(df, cut_1=929, cut_2=None, avg_end=1059, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 130
# Average Fx in the averaging interval [929:1059]: 4.535593998737824
# Average Fz in the averaging interval [929:1059]: 0.4380137908153045
# Maximum Fz in the plotting interval [929:None]: 0.7561360677083333 at timestep 1023
# Time step where Fx drops below 1: 1059

# %% [markdown]
# <font size="6">Test 6: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241748.csv"
df = pd.read_csv(data)
test_6, end_6 = plot_forces(df, cut_1=1000, cut_2=None, avg_end=1084, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 84
# Average Fx in the averaging interval [1000:1084]: 5.166862173307509
# Average Fz in the averaging interval [1000:1084]: 0.0736562093098958
# Maximum Fz in the plotting interval [1000:None]: 0.4181640625 at timestep 1070
# Time step where Fx drops below 1: 1084

# %% [markdown]
# <font size="6">Test 7: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241749.csv"
df = pd.read_csv(data)
test_7, end_7 = plot_forces(df, cut_1=1290, cut_2=None, avg_end=2024, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 734
# Average Fx in the averaging interval [1290:2024]: 5.264254928349799
# Average Fz in the averaging interval [1290:2024]: 0.8128156365750596
# Maximum Fz in the plotting interval [1290:None]: 2.130810546875 at timestep 1672
# Time step where Fx drops below 1: 2024

# %% [markdown]
# <font size="6">Test 8: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241750.csv"
df = pd.read_csv(data)
test_8, end_8 = plot_forces(df, cut_1=740, cut_2=None, avg_end=1107, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 367
# Average Fx in the averaging interval [740:1107]: 5.497272685827936
# Average Fz in the averaging interval [740:1107]: 0.37260381852790075
# Maximum Fz in the plotting interval [740:None]: 1.5196004231770832 at timestep 991
# Time step where Fx drops below 1: 1107

# %% [markdown]
# <font size="6">Test 9: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241751.csv"
df = pd.read_csv(data)
test_9, end_9 = plot_forces(df, cut_1=700, cut_2=None, avg_end=1000, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 300
# Average Fx in the averaging interval [700:1000]: 5.587497684160868
# Average Fz in the averaging interval [700:1000]: 0.41980428059895836
# Maximum Fz in the plotting interval [700:None]: 0.8679728190104167 at timestep 889
# Time step where Fx drops below 1: 1000

# %% [markdown]
# <font size="6">Test 10: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241752.csv"
df = pd.read_csv(data)
test_10, end_10 = plot_forces(df, cut_1=430, cut_2=None, avg_end=1209, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 779
# Average Fx in the averaging interval [430:1209]: 5.530716567882167
# Average Fz in the averaging interval [430:1209]: 1.2844823508370773
# Maximum Fz in the plotting interval [430:None]: 2.6486857096354166 at timestep 1165
# Time step where Fx drops below 1: 1209

# %% [markdown]
# <font size="6">Test 11: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_80_5N//log_202405241753.csv"
df = pd.read_csv(data)
test_11, end_11 = plot_forces(df, cut_1=710, cut_2=None, avg_end=1091, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 381
# Average Fx in the averaging interval [710:1091]: 5.954712962353323
# Average Fz in the averaging interval [710:1091]: 0.4959696291625656
# Maximum Fz in the plotting interval [710:None]: 1.00440673828125 at timestep 1084
# Time step where Fx drops below 1: 1091

# %%
def plot_multiple_tests(tests, ends):
    # Find the maximum length among all datasets
    max_length = max([end for end in ends if end is not None])
    
    plt.figure(figsize=(15, 7))
    
    for i, (test, end) in enumerate(zip(tests, ends)):
        if end is not None:
            fz_series = test['Fz']
            fz_series_cut = fz_series[:end]
            if len(fz_series_cut) < max_length:
                padded_fz = np.pad(fz_series_cut.values, (0, max_length - len(fz_series_cut)), 'constant', constant_values=np.nan)
            else:
                padded_fz = fz_series_cut.values
            plt.plot(padded_fz, label=f'Dataset {i+1} Fz', alpha=0.6)
        
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Normal Force (Fz) (N)')
    plt.legend()
    plt.title('Normal Force (Fz) of Multiple Datasets')
    plt.grid()
    plt.show()

# %%
tests = [test_1, test_2, test_3, test_4, test_5, test_6, test_7, test_8, test_9, test_10, test_11]
ends = [end_1, end_2, end_3, end_4, end_5, end_6, end_7, end_8, end_9, end_10, end_11]
plot_multiple_tests(tests, ends)
