# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_forces(df, cut_1=0, cut_2=None, avg_end=None, fx_threshold=1, offset_position='beginning', offset_length=10):
    """
    Plots the Tangential Force (Fx) and Normal Force (Fz) from the given DataFrame with offsets
    and within a specified range.

    Parameters:
    df (pd.DataFrame): The DataFrame containing force data with columns 'Fx' and 'Fz'.
    cut_1 (int): The starting index for the range of data to be plotted.
    cut_2 (int or None): The ending index for the range of data to be plotted. If None, plot till the end.

    Returns:
    None
    """
    if offset_position == 'beginning':
        # Calculate the offsets as the average of the first 20 entries
        offset_x = df['Fx'][:offset_length].mean()
        offset_z = df['Fz'][:offset_length].mean()
    elif offset_position == 'end':
        # Calculate the offsets as the average of the last 20 entries
        offset_x = df['Fx'][-offset_length:].mean()
        offset_z = df['Fz'][-offset_length:].mean()
    else:
        raise ValueError("Invalid offset_position. Choose either 'beginning' or 'end'.")

    # If avg_end is not provided, use cut_2
    avg_end = avg_end if avg_end is not None else cut_2

    # If avg_end is not None, calculate the length from cut_1 to avg_end
    if avg_end is not None and cut_1 is not None:
        length_cut_to_avg = avg_end - cut_1
        print(f"Length from cut_1 to avg_end: {length_cut_to_avg}")

    # Calculate average values of Fx and Fz in the defined averaging interval
    avg_fx = df[cut_1:avg_end]['Fx'].mean() - offset_x
    avg_fz = df[cut_1:avg_end]['Fz'].mean() - offset_z

    # Apply the cut range to the DataFrame
    df_cut = df[cut_1:cut_2].copy()
    
    # Find the maximum Fz and corresponding timestep
    max_fz = df_cut['Fz'].max() - offset_z
    max_fz_timestep = df_cut['Fz'].idxmax()

    # Find the timestep where Fx drops below the threshold
    fx_drop_timestep = df_cut[df_cut['Fx'] - offset_x < fx_threshold].index.min()
    
    # Print the average values
    print(f"Average Fx in the averaging interval [{cut_1}:{avg_end}]: {avg_fx}")
    print(f"Average Fz in the averaging interval [{cut_1}:{avg_end}]: {avg_fz}")
    print(f"Maximum Fz in the plotting interval [{cut_1}:{cut_2}]: {max_fz} at timestep {max_fz_timestep}")
    print(f"Time step where Fx drops below {fx_threshold}: {fx_drop_timestep}")
    
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'] - offset_x, label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'] - offset_z, label='Normal Force (Fz)', alpha=0.7)
    plt.axvline(x=max_fz_timestep, color='r', linestyle='--', label='Max Fz', alpha=0.2)
    plt.axvline(x=fx_drop_timestep, color='g', linestyle='--', label=f'Fx < {fx_threshold}', alpha=0.2)
    plt.xlabel('Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Tangential vs Normal Force (Offset Adjusted)')
    plt.grid()
    plt.show()

    # Apply the offsets to the cut DataFrame
    df_cut['Fx'] = df_cut['Fx'] - offset_x
    df_cut['Fz'] = df_cut['Fz'] - offset_z
    
    # Shift the index so it starts at 0 if cut_1 is not None
    if cut_1 is not None:
        df_cut.index = df_cut.index - cut_1

    # Return the modified DataFrame
    return df_cut, (length_cut_to_avg if avg_end is not None and cut_1 is not None else None)

# %%
def plot_modified_df(df_cut):
    """
    Plots the modified DataFrame with adjusted time steps.

    Parameters:
    df_cut (pd.DataFrame): The modified DataFrame with adjusted time steps.

    Returns:
    None
    """
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'], label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'], label='Normal Force (Fz)', alpha=0.7)
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Modified Tangential vs Normal Force (Adjusted Timesteps)')
    plt.grid()
    plt.show()

# %% [markdown]
# <font size="6">Schieferstein 90°</font>

# %% [markdown]
# <font size="6">Test 1: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_90_5N//log_202405231849.csv"
df = pd.read_csv(data)
test_1, end_1 = plot_forces(df, cut_1=740, cut_2=1198, avg_end=1183, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 443
# Average Fx in the averaging interval [740:1183]: 5.688089012722937
# Average Fz in the averaging interval [740:1183]: 0.4082053018746473
# Maximum Fz in the plotting interval [740:1198]: 0.9247802734375 at timestep 1047
# Time step where Fx drops below 1: 1183

# %% [markdown]
# <font size="6">Test 2: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_90_5N//log_202405231851.csv"
df = pd.read_csv(data)
test_2, end_2 = plot_forces(df, cut_1=980, cut_2=1354, avg_end=1337, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 357
# Average Fx in the averaging interval [980:1337]: 6.262452121542281
# Average Fz in the averaging interval [980:1337]: 0.5317780481333159
# Maximum Fz in the plotting interval [980:1354]: 1.3698811848958332 at timestep 1318
# Time step where Fx drops below 1: 1337

# %% [markdown]
# <font size="6">Test 3: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_90_5N//log_202405231852.csv"
df = pd.read_csv(data)
test_3, end_3 = plot_forces(df, cut_1=930, cut_2=1503, avg_end=1484, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 554
# Average Fx in the averaging interval [930:1484]: 5.852806603549907
# Average Fz in the averaging interval [930:1484]: 0.1656849040594916
# Maximum Fz in the plotting interval [930:1503]: 0.6610026041666667 at timestep 1412
# Time step where Fx drops below 1: 1484

# %% [markdown]
# <font size="6">Test 4: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_90_5N//log_202405231853.csv"
df = pd.read_csv(data)
test_4, end_4 = plot_forces(df, cut_1=1365, cut_2=None, avg_end=1733, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 368
# Average Fx in the averaging interval [1365:1733]: 6.212987702307493
# Average Fz in the averaging interval [1365:1733]: 0.6034375508626302
# Maximum Fz in the plotting interval [1365:None]: 1.8410359700520833 at timestep 1729
# Time step where Fx drops below 1: 1733

# %% [markdown]
# <font size="6">Test 5: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_90_5N//log_202405231854.csv"
df = pd.read_csv(data)
test_5, end_5 = plot_forces(df, cut_1=1050, cut_2=1250, avg_end=1236, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 186
# Average Fx in the averaging interval [1050:1236]: 5.7487935179023335
# Average Fz in the averaging interval [1050:1236]: 0.26755220146589387
# Maximum Fz in the plotting interval [1050:1250]: 0.7334391276041667 at timestep 1218
# Time step where Fx drops below 1: 1236

# %% [markdown]
# <font size="6">Test 6: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_90_5N//log_202405231856.csv"
df = pd.read_csv(data)
test_6, end_6 = plot_forces(df, cut_1=1020, cut_2=1560, avg_end=1505, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 485
# Average Fx in the averaging interval [1020:1505]: 6.126893860695698
# Average Fz in the averaging interval [1020:1505]: 0.5802197433419244
# Maximum Fz in the plotting interval [1020:1560]: 1.8385050455729166 at timestep 1477
# Time step where Fx drops below 1: 1505

# %% [markdown]
# <font size="6">Test 7: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_90_5N//log_202405231857.csv"
df = pd.read_csv(data)
test_7, end_7 = plot_forces(df, cut_1=1715, cut_2=None, avg_end=1862, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 147
# Average Fx in the averaging interval [1715:1862]: 5.486585406219067
# Average Fz in the averaging interval [1715:1862]: 0.24623010336947282
# Maximum Fz in the plotting interval [1715:None]: 0.5105916341145833 at timestep 1823
# Time step where Fx drops below 1: 1862

# %% [markdown]
# <font size="6">Test 8: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_90_5N//log_202405231859.csv"
df = pd.read_csv(data)
test_8, end_8 = plot_forces(df, cut_1=1050, cut_2=1223, avg_end=1208, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 158
# Average Fx in the averaging interval [1050:1208]: 5.604315853521291
# Average Fz in the averaging interval [1050:1208]: 0.24794965655491827
# Maximum Fz in the plotting interval [1050:1223]: 0.6209513346354167 at timestep 1190
# Time step where Fx drops below 1: 1208

# %% [markdown]
# <font size="6">Test 9: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_90_5N//log_202405231900.csv"
df = pd.read_csv(data)
test_9, end_9 = plot_forces(df, cut_1=1345, cut_2=None, avg_end=1746, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 401
# Average Fx in the averaging interval [1345:1746]: 5.779835956966688
# Average Fz in the averaging interval [1345:1746]: 0.5186581783659341
# Maximum Fz in the plotting interval [1345:None]: 0.9580240885416667 at timestep 1664
# Time step where Fx drops below 1: 1746

# %% [markdown]
# <font size="6">Test 10: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Schieferstein_90_5N//log_202405231901.csv"
df = pd.read_csv(data)
test_10, end_10 = plot_forces(df, cut_1=1675, cut_2=None, avg_end=1900, offset_position='end', offset_length=30)
# Out:
# Length from cut_1 to avg_end: 225
# Average Fx in the averaging interval [1675:1900]: 5.047741720411512
# Average Fz in the averaging interval [1675:1900]: 0.3705227322048611
# Maximum Fz in the plotting interval [1675:None]: 0.836083984375 at timestep 1869
# Time step where Fx drops below 1: 1900

# %%
def plot_multiple_tests(tests, ends):
    # Find the maximum length among all datasets
    max_length = max([end for end in ends if end is not None])
    
    plt.figure(figsize=(15, 7))
    
    for i, (test, end) in enumerate(zip(tests, ends)):
        if end is not None:
            fz_series = test['Fz']
            fz_series_cut = fz_series[:end]
            if len(fz_series_cut) < max_length:
                padded_fz = np.pad(fz_series_cut.values, (0, max_length - len(fz_series_cut)), 'constant', constant_values=np.nan)
            else:
                padded_fz = fz_series_cut.values
            plt.plot(padded_fz, label=f'Dataset {i+1} Fz', alpha=0.6)
        
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Normal Force (Fz) (N)')
    plt.legend()
    plt.title('Normal Force (Fz) of Multiple Datasets')
    plt.grid()
    plt.show()

# %%
tests = [test_1, test_2, test_3, test_4, test_5, test_6, test_7, test_8, test_9, test_10]
ends = [end_1, end_2, end_3, end_4, end_5, end_6, end_7, end_8, end_9, end_10]
plot_multiple_tests(tests, ends)
