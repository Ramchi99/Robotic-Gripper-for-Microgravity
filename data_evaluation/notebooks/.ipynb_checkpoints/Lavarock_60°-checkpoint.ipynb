# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_forces(df, cut_1=0, cut_2=None, avg_end=None, fx_threshold=1, offset_position='beginning', offset_length=10):
    """
    Plots the Tangential Force (Fx) and Normal Force (Fz) from the given DataFrame with offsets
    and within a specified range.

    Parameters:
    df (pd.DataFrame): The DataFrame containing force data with columns 'Fx' and 'Fz'.
    cut_1 (int): The starting index for the range of data to be plotted.
    cut_2 (int or None): The ending index for the range of data to be plotted. If None, plot till the end.

    Returns:
    None
    """
    if offset_position == 'beginning':
        # Calculate the offsets as the average of the first 20 entries
        offset_x = df['Fx'][:offset_length].mean()
        offset_z = df['Fz'][:offset_length].mean()
    elif offset_position == 'end':
        # Calculate the offsets as the average of the last 20 entries
        offset_x = df['Fx'][-offset_length:].mean()
        offset_z = df['Fz'][-offset_length:].mean()
    else:
        raise ValueError("Invalid offset_position. Choose either 'beginning' or 'end'.")

    # If avg_end is not provided, use cut_2
    avg_end = avg_end if avg_end is not None else cut_2

    # If avg_end is not None, calculate the length from cut_1 to avg_end
    if avg_end is not None and cut_1 is not None:
        length_cut_to_avg = avg_end - cut_1
        print(f"Length from cut_1 to avg_end: {length_cut_to_avg}")

    # Calculate average values of Fx and Fz in the defined averaging interval
    avg_fx = df[cut_1:avg_end]['Fx'].mean() - offset_x
    avg_fz = df[cut_1:avg_end]['Fz'].mean() - offset_z

    # Apply the cut range to the DataFrame
    df_cut = df[cut_1:cut_2].copy()
    
    # Find the maximum Fz and corresponding timestep
    max_fz = df_cut['Fz'].max() - offset_z
    max_fz_timestep = df_cut['Fz'].idxmax()

    # Find the timestep where Fx drops below the threshold
    fx_drop_timestep = df_cut[df_cut['Fx'] - offset_x < fx_threshold].index.min()
    
    # Print the average values
    print(f"Average Fx in the averaging interval [{cut_1}:{avg_end}]: {avg_fx}")
    print(f"Average Fz in the averaging interval [{cut_1}:{avg_end}]: {avg_fz}")
    print(f"Maximum Fz in the plotting interval [{cut_1}:{cut_2}]: {max_fz} at timestep {max_fz_timestep}")
    print(f"Time step where Fx drops below {fx_threshold}: {fx_drop_timestep}")
    
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'] - offset_x, label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'] - offset_z, label='Normal Force (Fz)', alpha=0.7)
    plt.axvline(x=max_fz_timestep, color='r', linestyle='--', label='Max Fz', alpha=0.2)
    plt.axvline(x=fx_drop_timestep, color='g', linestyle='--', label=f'Fx < {fx_threshold}', alpha=0.2)
    plt.xlabel('Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Tangential vs Normal Force (Offset Adjusted)')
    plt.grid()
    plt.show()

    # Apply the offsets to the cut DataFrame
    df_cut['Fx'] = df_cut['Fx'] - offset_x
    df_cut['Fz'] = df_cut['Fz'] - offset_z
    
    # Shift the index so it starts at 0 if cut_1 is not None
    if cut_1 is not None:
        df_cut.index = df_cut.index - cut_1

    # Return the modified DataFrame
    return df_cut, (length_cut_to_avg if avg_end is not None and cut_1 is not None else None)

# %% [markdown]
# <font size="6">Lavarock 60°</font>

# %% [markdown]
# <font size="6">Test 1: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211832.csv"
df = pd.read_csv(data)
test_1, end_1 = plot_forces(df, cut_1=840, cut_2=None, avg_end=1623, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 783
# Average Fx in the averaging interval [840:1623]: 4.826660320189417
# Average Fz in the averaging interval [840:1623]: 1.764864625114743
# Maximum Fz in the plotting interval [840:None]: 3.2395304361979167 at timestep 1597
# Time step where Fx drops below 1: 1049

# %% [markdown]
# <font size="6">Test 2: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211834.csv"
df = pd.read_csv(data)
test_2, end_2 = plot_forces(df, cut_1=1040, cut_2=None, avg_end=2161, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 1121
# Average Fx in the averaging interval [1040:2161]: 4.99453913333903
# Average Fz in the averaging interval [1040:2161]: 1.9539625446320714
# Maximum Fz in the plotting interval [1040:None]: 4.154606119791667 at timestep 2142
# Time step where Fx drops below 1: 2161

# %% [markdown]
# <font size="6">Test 3: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211837.csv"
df = pd.read_csv(data)
test_3, end_3 = plot_forces(df, cut_1=900, cut_2=None, avg_end=2437, offset_position='end', offset_length=15, fx_threshold=0.2)
# Out:
# Length from cut_1 to avg_end: 1537
# Average Fx in the averaging interval [900:2437]: 5.028334206879152
# Average Fz in the averaging interval [900:2437]: 3.718618317080588
# Maximum Fz in the plotting interval [900:None]: 6.638741048177083 at timestep 2414
# Time step where Fx drops below 0.2: 2437

# %% [markdown]
# <font size="6">Test 4a: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211839.csv"
df = pd.read_csv(data)
test_4a, end_4a = plot_forces(df, cut_1=800, cut_2=1260, avg_end=1187, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 387
# Average Fx in the averaging interval [800:1187]: 4.70233772016619
# Average Fz in the averaging interval [800:1187]: 1.1038652760113858
# Maximum Fz in the plotting interval [800:1260]: 2.1639811197916665 at timestep 1181
# Time step where Fx drops below 1: 1187

# %% [markdown]
# <font size="6">Test 4b: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211839.csv"
df = pd.read_csv(data)
test_4b, end_4b = plot_forces(df, cut_1=1293, cut_2=None, avg_end=1879, offset_position='end', offset_length=15, fx_threshold=0.2)
# Out:
# Length from cut_1 to avg_end: 586
# Average Fx in the averaging interval [1293:1879]: 4.789171588081819
# Average Fz in the averaging interval [1293:1879]: 1.9386375314410906
# Maximum Fz in the plotting interval [1293:None]: 2.6070841471354167 at timestep 1664
# Time step where Fx drops below 0.2: 1879

# %% [markdown]
# <font size="6">Test 5: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211843.csv"
df = pd.read_csv(data)
test_5, end_5 = plot_forces(df, cut_1=1395, cut_2=None, avg_end=2394, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 999
# Average Fx in the averaging interval [1395:2394]: 5.078634038319937
# Average Fz in the averaging interval [1395:2394]: 2.185564311870464
# Maximum Fz in the plotting interval [1395:None]: 4.234879557291666 at timestep 2370
# Time step where Fx drops below 1: 2394

# %% [markdown]
# <font size="6">Test 6: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211845.csv"
df = pd.read_csv(data)
test_6, end_6 = plot_forces(df, cut_1=800, cut_2=None, avg_end=2316, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 1516
# Average Fx in the averaging interval [800:2316]: 5.0450005254728705
# Average Fz in the averaging interval [800:2316]: 3.0997239138855677
# Maximum Fz in the plotting interval [800:None]: 5.841670735677083 at timestep 2260
# Time step where Fx drops below 1: 1100

# %% [markdown]
# <font size="6">Test 7a: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211847.csv"
df = pd.read_csv(data)
test_7a, end_7a = plot_forces(df, cut_1=119, cut_2=908, avg_end=892, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 773
# Average Fx in the averaging interval [119:892]: 4.514505526298795
# Average Fz in the averaging interval [119:892]: 1.162693807018785
# Maximum Fz in the plotting interval [119:908]: 1.9411295572916667 at timestep 838
# Time step where Fx drops below 1: 892

# %% [markdown]
# <font size="6">Test 7b: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211847.csv"
df = pd.read_csv(data)
test_7b, end_7b = plot_forces(df, cut_1=1230, cut_2=None, avg_end=2038, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 808
# Average Fx in the averaging interval [1230:2038]: 5.247487666898041
# Average Fz in the averaging interval [1230:2038]: 1.7166010840891217
# Maximum Fz in the plotting interval [1230:None]: 3.0871866861979167 at timestep 2020
# Time step where Fx drops below 1: 2038

# %% [markdown]
# <font size="6">Test 8: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211849.csv"
df = pd.read_csv(data)
test_8, end_8 = plot_forces(df, cut_1=710, cut_2=None, avg_end=2177, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 1467
# Average Fx in the averaging interval [710:2177]: 5.299866718716092
# Average Fz in the averaging interval [710:2177]: 2.21053123136077
# Maximum Fz in the plotting interval [710:None]: 5.69742431640625 at timestep 2173
# Time step where Fx drops below 1: 1645

# %% [markdown]
# <font size="6">Test 9a: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211852.csv"
df = pd.read_csv(data)
test_9a, end_9a = plot_forces(df, cut_1=715, cut_2=1180, avg_end=1137, offset_position='end', offset_length=15, fx_threshold=0.1)
# Out:
# Length from cut_1 to avg_end: 422
# Average Fx in the averaging interval [715:1137]: 5.450837691850949
# Average Fz in the averaging interval [715:1137]: 0.7552445590966874
# Maximum Fz in the plotting interval [715:1180]: 1.7916300455729166 at timestep 1078
# Time step where Fx drops below 0.1: 1137

# %% [markdown]
# <font size="6">Test 9b: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211852.csv"
df = pd.read_csv(data)
test_9b, end_9b = plot_forces(df, cut_1=1209, cut_2=None, avg_end=1888, offset_position='end', offset_length=15, fx_threshold=1)
# Out:
# Length from cut_1 to avg_end: 679
# Average Fx in the averaging interval [1209:1888]: 4.432641065922449
# Average Fz in the averaging interval [1209:1888]: 1.792329028452151
# Maximum Fz in the plotting interval [1209:None]: 3.0996134440104166 at timestep 1799
# Time step where Fx drops below 1: 1463

# %% [markdown]
# <font size="6">Test 10: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_60_5N//log_202405211854.csv"
df = pd.read_csv(data)
test_10, end_10 = plot_forces(df, cut_1=520, cut_2=1250, avg_end=1148, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 628
# Average Fx in the averaging interval [520:1148]: 5.260953817296686
# Average Fz in the averaging interval [520:1148]: 1.0690430076258957
# Maximum Fz in the plotting interval [520:1250]: 2.3436279296875 at timestep 1129
# Time step where Fx drops below 1: 1149

# %%
def plot_multiple_tests(tests, ends):
    # Find the maximum length among all datasets
    max_length = max([end for end in ends if end is not None])
    
    plt.figure(figsize=(15, 7))
    
    for i, (test, end) in enumerate(zip(tests, ends)):
        if end is not None:
            fz_series = test['Fz']
            fz_series_cut = fz_series[:end]
            if len(fz_series_cut) < max_length:
                padded_fz = np.pad(fz_series_cut.values, (0, max_length - len(fz_series_cut)), 'constant', constant_values=np.nan)
            else:
                padded_fz = fz_series_cut.values
            plt.plot(padded_fz, label=f'Dataset {i+1} Fz', alpha=0.6)
        
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Normal Force (Fz) (N)')
    plt.legend()
    plt.title('Normal Force (Fz) of Multiple Datasets')
    plt.grid()
    plt.show()

# %%
tests = [test_1, test_2, test_3, test_4a, test_4b, test_5, test_6, test_7a, test_7b, test_8, test_9a, test_9b, test_10]
ends = [end_1, end_2, end_3, end_4a, end_4b, end_5, end_6, end_7a, end_7b, end_8, end_9a, end_9b, end_10]
plot_multiple_tests(tests, ends)
