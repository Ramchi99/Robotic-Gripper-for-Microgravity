# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_forces(df, cut_1=0, cut_2=None, avg_end=None, fx_threshold=1, offset_position='beginning', offset_length=10):
    """
    Plots the Tangential Force (Fx) and Normal Force (Fz) from the given DataFrame with offsets
    and within a specified range.

    Parameters:
    df (pd.DataFrame): The DataFrame containing force data with columns 'Fx' and 'Fz'.
    cut_1 (int): The starting index for the range of data to be plotted.
    cut_2 (int or None): The ending index for the range of data to be plotted. If None, plot till the end.

    Returns:
    None
    """
    if offset_position == 'beginning':
        # Calculate the offsets as the average of the first 20 entries
        offset_x = df['Fx'][:offset_length].mean()
        offset_z = df['Fz'][:offset_length].mean()
    elif offset_position == 'end':
        # Calculate the offsets as the average of the last 20 entries
        offset_x = df['Fx'][-offset_length:].mean()
        offset_z = df['Fz'][-offset_length:].mean()
    else:
        raise ValueError("Invalid offset_position. Choose either 'beginning' or 'end'.")

    # If avg_end is not provided, use cut_2
    avg_end = avg_end if avg_end is not None else cut_2

    # If avg_end is not None, calculate the length from cut_1 to avg_end
    if avg_end is not None and cut_1 is not None:
        length_cut_to_avg = avg_end - cut_1
        print(f"Length from cut_1 to avg_end: {length_cut_to_avg}")

    # Calculate average values of Fx and Fz in the defined averaging interval
    avg_fx = df[cut_1:avg_end]['Fx'].mean() - offset_x
    avg_fz = df[cut_1:avg_end]['Fz'].mean() - offset_z

    # Apply the cut range to the DataFrame
    df_cut = df[cut_1:cut_2].copy()
    
    # Find the maximum Fz and corresponding timestep
    max_fz = df_cut['Fz'].max() - offset_z
    max_fz_timestep = df_cut['Fz'].idxmax()

    # Find the timestep where Fx drops below the threshold
    fx_drop_timestep = df_cut[df_cut['Fx'] - offset_x < fx_threshold].index.min()
    
    # Print the average values
    print(f"Average Fx in the averaging interval [{cut_1}:{avg_end}]: {avg_fx}")
    print(f"Average Fz in the averaging interval [{cut_1}:{avg_end}]: {avg_fz}")
    print(f"Maximum Fz in the plotting interval [{cut_1}:{cut_2}]: {max_fz} at timestep {max_fz_timestep}")
    print(f"Time step where Fx drops below {fx_threshold}: {fx_drop_timestep}")
    
    plt.figure(figsize=(10, 5))
    plt.plot(df_cut['Fx'] - offset_x, label='Tangential Force (Fx)', alpha=0.7)
    plt.plot(df_cut['Fz'] - offset_z, label='Normal Force (Fz)', alpha=0.7)
    plt.axvline(x=max_fz_timestep, color='r', linestyle='--', label='Max Fz', alpha=0.2)
    plt.axvline(x=fx_drop_timestep, color='g', linestyle='--', label=f'Fx < {fx_threshold}', alpha=0.2)
    plt.xlabel('Timesteps')
    plt.ylabel('Force (N)')
    plt.legend()
    plt.title('Tangential vs Normal Force (Offset Adjusted)')
    plt.grid()
    plt.show()

    # Apply the offsets to the cut DataFrame
    df_cut['Fx'] = df_cut['Fx'] - offset_x
    df_cut['Fz'] = df_cut['Fz'] - offset_z
    
    # Shift the index so it starts at 0 if cut_1 is not None
    if cut_1 is not None:
        df_cut.index = df_cut.index - cut_1

    # Return the modified DataFrame
    return df_cut, (length_cut_to_avg if avg_end is not None and cut_1 is not None else None)

# %% [markdown]
# <font size="6">Lavarock 90°</font>

# %% [markdown]
# <font size="6">Test 1: (failed)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_90_5N//log_202405211543.csv"
df = pd.read_csv(data)
test_1, end_1 = plot_forces(df, cut_1=None, cut_2=None, avg_end=None, offset_position='beginning', offset_length=15)
# Out:
# Average Fx in the averaging interval [None:None]: 3.9926403148463128
# Average Fz in the averaging interval [None:None]: -1.8722653576317592
# Maximum Fz in the plotting interval [None:None]: 0.2788411458333333 at timestep 750
# Time step where Fx drops below 1: 0

# %% [markdown]
# <font size="6">Test 2: (failed)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_90_5N//log_202405211548.csv"
df = pd.read_csv(data)
test_2, end_2 = plot_forces(df, cut_1=None, cut_2=None, avg_end=None, offset_position='beginning', offset_length=15)
# Out:
# Average Fx in the averaging interval [None:None]: 4.229327323219993
# Average Fz in the averaging interval [None:None]: -0.9007866162291795
# Maximum Fz in the plotting interval [None:None]: 0.2680297851562501 at timestep 669
# Time step where Fx drops below 1: 0

# %% [markdown]
# <font size="6">Test 3: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_90_5N//log_202405211550.csv"
df = pd.read_csv(data)
test_3, end_3 = plot_forces(df, cut_1=400, cut_2=861, avg_end=846, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 446
# Average Fx in the averaging interval [400:846]: 5.000272867747308
# Average Fz in the averaging interval [400:846]: 0.2874268125525503
# Maximum Fz in the plotting interval [400:861]: 0.8318237304687499 at timestep 808
# Time step where Fx drops below 1: 846

# %% [markdown]
# <font size="6">Test 4: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_90_5N//log_202405211553.csv"
df = pd.read_csv(data)
test_4, end_4 = plot_forces(df, cut_1=730, cut_2=1077, avg_end=1059, offset_position='beginning', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 329
# Average Fx in the averaging interval [730:1059]: 5.062274551005108
# Average Fz in the averaging interval [730:1059]: 0.6243712698676545
# Maximum Fz in the plotting interval [730:1077]: 1.4819376627604166 at timestep 1052
# Time step where Fx drops below 1: 1059

# %% [markdown]
# <font size="6">Test 5: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_90_5N//log_202405211555.csv"
df = pd.read_csv(data)
test_5, end_5 = plot_forces(df, cut_1=710, cut_2=1107, avg_end=1085, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 375
# Average Fx in the averaging interval [710:1085]: 6.219977692921956
# Average Fz in the averaging interval [710:1085]: 0.8046223958333332
# Maximum Fz in the plotting interval [710:1107]: 1.6601481119791666 at timestep 1048
# Time step where Fx drops below 1: 1086

# %% [markdown]
# <font size="6">Test 6: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_90_5N//log_202405211724.csv"
df = pd.read_csv(data)
test_6, end_6 = plot_forces(df, cut_1=895, cut_2=1200, avg_end=1143, offset_position='end', offset_length=30)
# Out:
# Length from cut_1 to avg_end: 248
# Average Fx in the averaging interval [895:1143]: 5.507547392768245
# Average Fz in the averaging interval [895:1143]: 0.6329047746555779
# Maximum Fz in the plotting interval [895:1200]: 1.2396158854166666 at timestep 1123
# Time step where Fx drops below 1: 1143

# %% [markdown]
# <font size="6">Test 7: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_90_5N//log_202405211727.csv"
df = pd.read_csv(data)
test_7, end_7 = plot_forces(df, cut_1=690, cut_2=959, avg_end=937, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 247
# Average Fx in the averaging interval [690:937]: 4.208141825491922
# Average Fz in the averaging interval [690:937]: 0.4601285082447706
# Maximum Fz in the plotting interval [690:959]: 1.1081380208333333 at timestep 918
# Time step where Fx drops below 1: 937

# %% [markdown]
# <font size="6">Test 8: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_90_5N//log_202405211729.csv"
df = pd.read_csv(data)
test_8, end_8 = plot_forces(df, cut_1=330, cut_2=501, avg_end=486, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 156
# Average Fx in the averaging interval [330:486]: 4.270483348308465
# Average Fz in the averaging interval [330:486]: 0.3347713372646234
# Maximum Fz in the plotting interval [330:501]: 0.9754069010416667 at timestep 481
# Time step where Fx drops below 1: 487

# %% [markdown]
# <font size="6">Test 9: (worked)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_90_5N//log_202405211731.csv"
df = pd.read_csv(data)
test_9, end_9 = plot_forces(df, cut_1=988, cut_2=None, avg_end=1315, offset_position='end', offset_length=15)
# Out:
# Length from cut_1 to avg_end: 327
# Average Fx in the averaging interval [988:1315]: 5.522920687264259
# Average Fz in the averaging interval [988:1315]: 0.5993703486357989
# Maximum Fz in the plotting interval [988:None]: 1.5082722981770833 at timestep 1312
# Time step where Fx drops below 1: 1315

# %% [markdown]
# <font size="6">Test 10: (failed)</font>

# %%
data = "C://Users//sramc//Documents//01_Studium//50_Bachelor's Thesis//07_Test//Gripper Test Microspines Angles//Lavarock_90_5N//log_202405211734.csv"
df = pd.read_csv(data)
test_10, end_10 = plot_forces(df, cut_1=None, cut_2=None, avg_end=None, offset_position='end', offset_length=40)
# Out:
# Average Fx in the averaging interval [None:None]: 2.906606648729356
# Average Fz in the averaging interval [None:None]: -0.5618923077604954
# Maximum Fz in the plotting interval [None:None]: 0.28321533203125 at timestep 62
# Time step where Fx drops below 1: 0

# %%
def plot_multiple_tests(tests, ends):
    # Find the maximum length among all datasets
    max_length = max([end for end in ends if end is not None])
    
    plt.figure(figsize=(15, 7))
    
    for i, (test, end) in enumerate(zip(tests, ends)):
        if end is not None:
            fz_series = test['Fz']
            fz_series_cut = fz_series[:end]
            if len(fz_series_cut) < max_length:
                padded_fz = np.pad(fz_series_cut.values, (0, max_length - len(fz_series_cut)), 'constant', constant_values=np.nan)
            else:
                padded_fz = fz_series_cut.values
            plt.plot(padded_fz, label=f'Dataset {i+1} Fz', alpha=0.6)
        
    plt.xlabel('Adjusted Timesteps')
    plt.ylabel('Normal Force (Fz) (N)')
    plt.legend()
    plt.title('Normal Force (Fz) of Multiple Datasets')
    plt.grid()
    plt.show()

# %%
tests = [test_3, test_4, test_5, test_6, test_7, test_8, test_9]
ends = [end_3, end_4, end_5, end_6, end_7, end_8, end_9]
plot_multiple_tests(tests, ends)
